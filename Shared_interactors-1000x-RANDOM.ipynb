# %% [markdown]
# # Shared Interactors Pipeline
#
# ### This pipeline takes as input user-defined groups of phospho-peptides (e.g. those with increased phosphorylation in response stimulus or those with decreased phosphorylation in response to stimulus). The first script partitions each group into ‘modules’ of phospho-peptides that share the same sequence motif around the phosphorylation site. The method then identifies Shared Interactors as described above for each identified module.
#
# #### Modified to run 1000x w/  a new randomized background network.  The randomized background networks were generated using BiRewire R package.
#
# #### Matt provided the input file to run: Input_SI_Identification_dashes_removed.csv
# #### File looks like
#
# Submodule,ORF<br>
# Induced_.....s..S..._cdc14_Induced_Amplified,YMR031C<br>
# Induced_.....s..S..._cdc14_Induced_Amplified,YHR131C<br>
# Induced_.....s..S..._cdc14_Induced_Defective,YBL061C<br>
#
# #### Other required files:
#
# 1) Number_Interactions_Each_Protein.csv
#
# Protein,Total<br>
# YPL031C,419<br>
# YBR160W,304<br>
# YHR135C,304<br>
#
# 2) Annotation.csv
#
# systematic_name_dash_removed,systematic_name<br>
# YKL134C,YKL134C<br>
# YMR056C,YMR056C<br>
# YBR085W,YBR085W<br>
# YJR155W,YJR155W<br>
#
# 3) rewired background network file, from BiRewire R package
#
# Protein1,Protein2,Interaction,Directed<br>
# CX101,YCL043C,metabolic_pathway,0<br>
# YCL043C,CX101,metabolic_pathway:reversed,0<br>
# CX18,YHR066W,metabolic_pathway,1<br>
# YHR066W,CX18,metabolic_pathway:reversed,1<br>

# %%
# load required libraries
import glob
import numpy as np
import os
import pandas as pd
import re
from scipy.stats import hypergeom

# enter base directory
baseDir  = '/home/mplace/projects/forMatt/Phospho_Network/forPaper/'
bgNetDir = '/home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/'

# %% [markdown]
# # Identify Shared Interactors
#
# This script identifies proteins enriched for interactions with Submodule constituent proteins, based on known interactions in the background network. We call these proteins 'Shared Interactors'. The background network is a protein
# interaction network curated in yeast under mostly nutrient replete conditions that contains 4638 proteins and ~ 25,000 interactions, including directed (ex; kinase-substrate), and
# non-directed.
#
# Proteins enriched for interactions with Submodule proteins at a 5% FDR, determined by a hypergeometric test and BH correction, are considered shared interactors.
#
# Shared Interactors represent numerous functional classes, including kinases and phosphatases. Kinase and phosphatase shared interactors represent potential Submodule regulators.
#
# HyperG function:
# distrib=hypergeom(N,M,n)
# distrib.pmf(m)
#
# * N - population size (4638 unique proteins in Background network file - phospho_v4_bgnet_siflike_withdirections_Matt_Modified.csv)
#
# * M - total number of successes  (# of interactions for a given protein. ie. Protein A has 200 known interactions in the background network).
#
# * n - the number of trials (also called sample size) -  ie. (Number of proteins that reside within a submdoule)
#
# * m - the number of successes - for example: Protein A, a shared interactor, has 35 interactions with proteins in Submodule B.
#
#
#  Final shared interactor file:   __Final_enriched.csv__  , this contains the significant Shared Interactors based on the
#  BH_significance test.
#
#  A list of all shared interactors can be found:  __Network_Submodule_Nodes_background_Network.csv__

# %%
# get a list of all randomized background network files
bgNTWKs = []
for bg in glob.glob(bgNetDir + 'rewired-BG-network-*.csv'):
    bgNTWKs.append(bg)
    
for b in bgNTWKs:
    print(b)
# Out:
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-807.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-66.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-289.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-522.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-474.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-7.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-577.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-938.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-463.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-41.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-305.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-235.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-473.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-170.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-209.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-901.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-710.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-189.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-877.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-32.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-698.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-869.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-920.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-743.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-686.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-493.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-603.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-895.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-511.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-555.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-273.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-883.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-943.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-87.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-363.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-443.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-162.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-301.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-990.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-46.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-436.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-153.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-659.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-487.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-936.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-9.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-638.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-105.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-33.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-523.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-896.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-831.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-535.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-465.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-484.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-729.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-779.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-476.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-31.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-644.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-855.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-387.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-947.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-217.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-707.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-814.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-508.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-393.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-72.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-652.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-328.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-844.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-632.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-439.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-433.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-928.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-285.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-332.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-408.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-454.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-325.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-324.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-83.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-583.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-925.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-829.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-955.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-458.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-352.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-357.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-207.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-663.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-249.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-61.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-284.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-728.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-43.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-606.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-122.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-872.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-15.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-104.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-566.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-579.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-455.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-145.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-608.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-349.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-69.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-765.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-114.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-825.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-451.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-317.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-359.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-460.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-719.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-854.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-183.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-441.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-74.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-502.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-378.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-280.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-888.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-437.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-545.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-383.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-166.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-406.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-271.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-274.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-738.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-880.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-91.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-635.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-666.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-374.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-885.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-866.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-633.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-607.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-851.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-449.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-248.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-407.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-681.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-870.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-215.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-47.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-761.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-119.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-241.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-853.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-975.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-261.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-890.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-138.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-94.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-348.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-470.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-868.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-981.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-291.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-919.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-346.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-875.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-959.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-806.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-627.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-498.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-445.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-175.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-865.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-396.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-220.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-519.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-107.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-592.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-982.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-335.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-601.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-848.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-694.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-727.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-852.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-942.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-796.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-219.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-725.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-778.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-582.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-178.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-39.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-255.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-379.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-835.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-262.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-556.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-206.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-587.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-775.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-25.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-702.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-887.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-612.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-932.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-754.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-501.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-636.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-313.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-385.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-471.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-293.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-832.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-816.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-10.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-434.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-224.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-48.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-92.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-239.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-185.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-208.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-21.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-826.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-794.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-889.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-923.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-783.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-204.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-574.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-746.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-85.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-747.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-444.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-752.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-957.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-152.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-934.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-771.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-616.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-962.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-759.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-602.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-971.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-198.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-230.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-226.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-695.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-914.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-850.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-963.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-720.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-964.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-71.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-23.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-745.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-60.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-978.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-554.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-464.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-699.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-295.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-516.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-676.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-375.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-905.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-142.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-599.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-867.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-580.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-88.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-893.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-57.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-811.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-491.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-420.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-140.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-63.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-199.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-758.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-862.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-782.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-299.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-469.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-334.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-245.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-642.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-790.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-605.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-998.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-882.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-993.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-899.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-841.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-791.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-777.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-813.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-559.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-704.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-781.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-258.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-429.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-550.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-110.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-509.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-70.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-250.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-724.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-639.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-165.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-570.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-4.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-737.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-622.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-958.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-277.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-911.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-472.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-623.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-136.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-858.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-34.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-203.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-252.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-569.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-984.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-244.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-282.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-309.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-751.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-680.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-933.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-711.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-169.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-546.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-543.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-902.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-706.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-409.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-520.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-99.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-817.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-631.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-977.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-717.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-78.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-760.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-450.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-552.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-967.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-812.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-267.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-298.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-792.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-242.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-499.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-892.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-221.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-768.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-769.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-671.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-949.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-789.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-960.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-438.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-186.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-951.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-62.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-643.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-976.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-176.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-810.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-38.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-537.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-588.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-916.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-677.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-411.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-115.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-655.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-319.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-67.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-589.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-548.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-137.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-80.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-108.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-419.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-624.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-111.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-619.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-392.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-232.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-581.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-985.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-536.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-192.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-921.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-1.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-662.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-558.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-822.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-370.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-553.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-290.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-873.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-931.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-833.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-247.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-860.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-442.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-753.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-263.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-19.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-368.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-147.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-210.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-529.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-98.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-65.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-780.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-837.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-478.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-721.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-27.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-510.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-389.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-237.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-690.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-163.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-35.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-918.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-948.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-417.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-381.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-799.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-922.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-847.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-44.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-834.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-281.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-736.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-194.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-617.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-544.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-604.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-956.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-793.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-997.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-489.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-1000.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-426.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-382.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-703.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-797.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-533.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-337.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-744.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-692.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-182.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-391.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-846.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-849.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-344.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-910.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-456.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-371.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-979.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-269.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-16.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-428.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-160.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-926.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-133.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-715.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-722.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-828.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-970.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-614.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-542.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-988.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-397.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-318.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-739.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-966.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-683.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-809.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-236.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-96.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-634.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-380.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-886.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-594.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-53.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-240.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-986.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-526.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-101.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-953.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-621.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-126.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-64.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-547.csv
# ...
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-927.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-712.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-900.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-51.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-795.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-657.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-102.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-991.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-654.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-400.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-423.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-830.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-398.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-935.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-58.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-503.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-734.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-840.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-946.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-735.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-341.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-320.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-225.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-342.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-353.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-836.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-364.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-718.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-231.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-740.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-24.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-55.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-803.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-321.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-679.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-904.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-174.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-347.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-109.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-394.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-669.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-307.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-435.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-818.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-97.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-302.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-495.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-549.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-156.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-714.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-361.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-878.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-467.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-798.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-340.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-567.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-494.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-620.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-151.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-447.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-50.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-424.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-974.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-874.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-994.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-246.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-11.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-845.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-670.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-190.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-767.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-143.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-12.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-29.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-507.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-81.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-164.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-369.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-146.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-772.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-367.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-482.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-961.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-197.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-821.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-756.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-452.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-457.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-496.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-992.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-750.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-490.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-672.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-292.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-937.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-413.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-843.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-427.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-373.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-954.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-479.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-132.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-665.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-173.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-630.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-336.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-213.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-651.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-372.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-741.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-154.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-857.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-82.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-786.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-664.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-701.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-304.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-800.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-894.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-49.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-130.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-73.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-705.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-764.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-275.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-842.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-972.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-924.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-762.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-264.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-521.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-37.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-404.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-157.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-950.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-205.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-766.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-684.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-191.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-410.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-973.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-539.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-763.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-861.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-784.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-515.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-827.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-118.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-640.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-563.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-700.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-688.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-134.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-530.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-338.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-564.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-431.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-674.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-996.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-184.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-578.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-356.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-528.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-422.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-40.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-399.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-168.csv
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-135.csv

# %%
Submodule_DF   = pd.read_csv(baseDir + '/Submodule_constituents.csv')   # File that contains Submodule names and their protein constituents                                                                                  # Background network of protein interactions
Num_Prot_Inter = pd.read_csv('/home/mplace/projects/forMatt/Phospho_Network/forPaper/SI_Input_Files/Number_Interactions_Each_Protein.csv')                                              # Number of protein interactions for each protein in the background network
Annotation_DF  = pd.read_csv('/home/mplace/projects/forMatt/Phospho_Network/forPaper/SI_Input_Files/Annotation.csv')                                                   # Yeast protein annotation file

for ntwk, i in zip(bgNTWKs, range(len(bgNTWKs))):
    BgNet = pd.read_csv(ntwk)
   
       
    Submodule_List=Submodule_DF['Submodule'].unique().tolist()                                                      # Send the Submodules to a list, but filter out duplicates, which there will be many, since the Submodules will have been found in many proteins.

    dicOrfs={}
    for Submodule in Submodule_List:                                                                                                                            # Key (Submodule), Value (Yeast ORFs that are Submodule constituents). Filter ORFs found twice to single occurence (important for enrichment analysis)
        dicOrfs[Submodule]=(Submodule_DF.loc[Submodule_DF['Submodule'] == Submodule])['ORF'].unique().tolist()


    dicOrfsCounts={}  
    for k,v in dicOrfs.items():  
        if k not in dicOrfsCounts:  
            value=len(v)            
            dicOrfsCounts[k]=value
    
    df_Submodule_Size=pd.DataFrame(list(dicOrfsCounts.items()),                                                                                                  # convert dict to dataframe.
                          columns=['Submodule','n'])

    def SliceDataframe():
        ''' For each Submodule identify all proteins that interact with the Submodule proteins in the background network '''
        lst = []
        for key in dicOrfs.keys():                                                                                                                             #Select the key, which is a Submodule, from the dict
            CurrentDF=BgNet.copy() 
            x=CurrentDF[CurrentDF['Protein1'].isin(dicOrfs[key])].rename(columns={'Protein1':'Submodule_Containing_Proteins', 'Protein2':'Possible_Shared_Interactors'})                              #Create a new dataframe that is a slice of the salt background network, and only contains proteins that were passed in "dicOrfs[key]". At the same time, rename the columns                                
            x['Submodule']=key 
            lst.append(x)

        return lst

    Sliced_dataframe_list= SliceDataframe()

    def Add_n():    
        ''' Function adds 'n', the number of proteins in the Submodule, to each dataframe'''
        lst= []
        for df in Sliced_dataframe_list:
            NewDF=df.merge(df_Submodule_Size)
            lst.append(NewDF)

        return lst

    Sliced_dataframe_list= Add_n()

    def Identify_Shared_Interactors():
        ''' Function identifies proteins that interact with at least 2 protein constituents of each submodule'''

        lst=[] 
        for df in Sliced_dataframe_list: 
            NewDF=df.copy()
            NewDF2=NewDF[NewDF.duplicated(['Possible_Shared_Interactors'], keep = 'last')| NewDF.duplicated(['Possible_Shared_Interactors'])]                  # Only retain proteins that interact with at least 2 submodule protein constituents
            x=NewDF2.sort_values(by='Possible_Shared_Interactors', ascending=True) 
            lst.append(x)

        return lst

    Shared_Interactors_lst=Identify_Shared_Interactors()

    def AppendDFs_that_Contain_AllSharedInteractors_and_their_targets():
        ''' Function appends all submodules and their shared interactors together into a single file'''
        EmptyDF = pd.DataFrame() 
        for df in Shared_Interactors_lst:  
            df=df.copy() 
            EmptyDF=EmptyDF.append(df)
        return EmptyDF

    SI_andTargets=AppendDFs_that_Contain_AllSharedInteractors_and_their_targets()
    
    ########## print(SI_andTargets.head())

    SI_andTargets_FINAL=pd.merge(left=SI_andTargets, right=Annotation_DF, how='left',
                                  left_on='Possible_Shared_Interactors', right_on='systematic_name_dash_removed') 
        

    # complete a merge so I can get the dashes back in the names, which are not included in the background network
    del SI_andTargets_FINAL['Possible_Shared_Interactors']                                                                                                      # drop because  lacks the dashes which are needed for the correct naming convention
    del SI_andTargets_FINAL['systematic_name_dash_removed']                                                                                                     # drop because carried over from the merge
    del SI_andTargets_FINAL['Directed']

    SI_andTargets_FINAL.columns = ['Submodule_Containing_Proteins', 'Interaction', 'Submodule', 'n','Possible_Shared_Interactors']                        # rename columns

    

    
    myDF = pd.DataFrame(SI_andTargets_FINAL)
    # OUTPUT NAME FOR SHARED INTERACTORS
    filename = 'SI_Identification_SubmoduleS__SIs_and_Targets_FDR-' + str(i) + '.csv'
    myDF.to_csv( baseDir + filename, index=False, encoding='utf-8' )              # All interactions between SIs and their submodule constituent proteins. No enrichment at this step.

    #-----------------------------------------------------------------------------------------------------------------------------------------------------------------------
    ''' Preparing dataframe for Hypergeometric test'''

    def Add_N_and_m():
        ''' Function adds 'N' and calculates 'm' values, which are inputs for the hypergeometric test, to the datframe'''
        lst=[]
        for df in Shared_Interactors_lst:
            NewDF=df.copy()
            NewDF['N'] = 4638          # THIS IS THE LENGTH OF THE DATA FRAME, *******************************                                                                                                                         # of proteins in the background network
            NewDF['m'] = NewDF.groupby('Possible_Shared_Interactors')['Possible_Shared_Interactors'].transform('count')
            lst.append(NewDF)

        return lst

    Dataframes_list_with_n_N_m=Add_N_and_m()

    #-----------------------------------------------------------------------------------------------------------------------------------------------------------------------


    def Drop_dups():
        ''' For each dataframe, which contains a single submodule, it's protein constituents, and shared interactors, drop duplicate entries for identified SI proteins
        . This leaves a single entry for each shared interactor protein. '''
        lst=[]
        for df in Dataframes_list_with_n_N_m:
            NewDF=df.copy()
            Final_DF=NewDF.drop_duplicates('Possible_Shared_Interactors')
            Final_DF=Final_DF.rename(columns={'Possible_Shared_Interactors':'Shared_Interactor'})
            lst.append(Final_DF)

        return lst

    Drop_Dups_lst=Drop_dups()


    def Return_M():
        ''' Function identifies 'M' (the total number of interactions for each Shared Interactor protein in the background network) and adds that number
        to the dataframe'''
        lst=[]
        for df in Drop_Dups_lst:
            NewDF=df.copy()
            NewDF2=df.copy()
            NewDF_lst=NewDF['Shared_Interactor'].tolist()                                                                                                            # place all proteins in the 'Shared_Interactor' column in a list 
            Shared_Interactors=Num_Prot_Inter[Num_Prot_Inter['Protein'].isin(NewDF_lst)].rename(columns={'Protein':'Shared_Interactor', 'Total':'M'})
            Shared_Interactor_merge=Shared_Interactors.merge(NewDF2, on='Shared_Interactor')
            Shared_Interactor_merge=Shared_Interactor_merge.sort_values(by='Shared_Interactor', ascending=True)
            lst.append(Shared_Interactor_merge)

        return lst

    Return_M_lst=Return_M()

    #-----------------------------------------------------------------------------------------------------------------------------------------
    def hyper(N,M,n,m): 
        ''' Function defines the parameters for a hypergeometric test that returns a p-value representing the chances of identifying >= x, where x is the number of successes '''  
        frozendist=hypergeom(N,M,n)
        ms=np.arange(m, min(n+1, M+1))
        rv=0;
        for single_m in ms: rv=rv+frozendist.pmf(single_m)
        return rv

    def run_hyper():
        ''' Function calls the hypergeometric function above  on each shared interactor for each submodule'''
        lst=[]
        for df in Return_M_lst:
            if not df.empty:
                NewDF=df.copy()
                NewDF['p-value'] = NewDF.apply(lambda row: hyper(row['N'], row['M'], row['n'], row['m']), axis=1)
                lst.append(NewDF)

        return lst 

    run_hyper_lst=run_hyper()

    #-----------------------------------------------------------------------------------------------------------------------------------------------------------------------
    def AppendDFs():
        ''' Append DFs for each submodule and it's SIs together into a single DF'''   
        EmptyDF = pd.DataFrame() #
        for df in run_hyper_lst: 
            df=df.copy() 
            EmptyDF=EmptyDF.append(df)
        return EmptyDF

    Final=AppendDFs()

    #-----------------------------------------------------------------------------------------------------------------------------------------------------------------------
    ''' Prepping for Benjamini Hochberg procedure. Below code is ranking p-values from 1 to n based on lowest to highest p-value score'''

    Final=Final.sort_values(by=['p-value'],ascending=[True])                                                                                              # Sort p-values from lowest to highest
    Final_resetIndex=Final.reset_index()                                                                                                        # Reset the index after the sort
    Final_resetIndex.index +=1                                                                                                                  # start numbering at 1 for index

    NewDF=Final_resetIndex
    NewDF_Allp_values=Final_resetIndex
    NewDF=NewDF[['p-value']]                                                                                                                    # select only the p-value column of the dataframe 
    NewDF_dropdups=NewDF.drop_duplicates('p-value')                                                                                             # drop duplicate p-values
    NewDF_dropdups=NewDF_dropdups.reset_index()                                                                                                 # reset the index
    NewDF_dropdups.index +=1                                                                                                                    # start numbering at 1 for index
    NewDF_dropdups['Rank(i)'] = NewDF_dropdups.index                                                                                            # #Add a rank column that will be filled with index values. 
    NewDF_dropdups=NewDF_dropdups.drop('index', 1)                                                                                              # Drop the additional column 'index' that is not sorted.
    NewDF_merge=NewDF_Allp_values.merge(NewDF_dropdups, on='p-value')                                                                           # create a new dataframe that is a merge of the dataframe with all p-values, and the dataframe with unique p-values and their ranks. 
    NewDF_merge=NewDF_merge.drop('index',1)                                                                                                     # drop the index that was added from the merge. This leaves all p-values ordered from lowest to highest with their ranking.

    '''Add parameters necessary for completing Benjamini-Hochberg procedure '''

    NewDF=NewDF_merge
    NewDF['m_(number_of_tests)']=(len(NewDF))                                                                                                   # Add 'm (number of tests)' column 
    NewDF['Q_(FDR)']=0.05      # THIS IS THE FDR VALUE, USER CAN CHANGE **************************************                                                                                                                 # Add Q (FDR) column. This can be changed manually.
    NewDF['(i/m)Q']=((NewDF['Rank(i)']/NewDF['m_(number_of_tests)'])*NewDF['Q_(FDR)'])                                                          # add the (i/m)Q column 
    NewDF['BH_significant']=NewDF.apply(lambda x: 1 if x['p-value']<x['(i/m)Q'] else 0, axis=1)                                                 # Identify which proteins are  significant. 
    NewDF=pd.merge(left=NewDF, right=Annotation_DF, how='left', left_on='Shared_Interactor', right_on='systematic_name_dash_removed')           # complete a merge to recover dashed version of YORFs
    del NewDF['Shared_Interactor'] 
    del NewDF['systematic_name_dash_removed']
    del NewDF['Directed']
    NewDF.columns = ['M','Submodule_Containing_Proteins', 'Interaction', 'Submodule', 'n','N','m','p-value','Rank(i)', 'm_(number_of_tests)', 'Q_(FDR)','(i/m)Q','BH_significant', 'Shared_Interactor'] # rename columns

    myDF = pd.DataFrame(NewDF)
    filename = 'Network_Submodule_Nodes_background_Network-' + str(i) + '.csv'
    myDF.to_csv( baseDir + filename, index=False, encoding='utf-8' )       # Write out final file with enriched shared interactors for each submodule


    # FILTER FOR THE FINAL Shared Interactors.
    # Open and parse Network_Submodule_Nodes_background_Network.csv 
    # Only keep the identified Shared Interactors about the first zero that appears in the BH_Significant column.
    with open(baseDir + 'Final_enriched-' + str(i) + '.csv', 'w') as outfile, open(baseDir + 'Network_Submodule_Nodes_background_Network-' + str(i) + '.csv', 'r') as f:
        for line in f:
            if line.startswith('M,'):
                outfile.write(line)
                continue
            dat = line.split(',')
            if dat[12] == '0':
                break
            else:
                outfile.write(line)

    f.close()
    outfile.close()

    # OUTPUT: SI_Identification_SubmoduleS__SIs_and_Targets_FDR.csv, 
    #         Network_Submodule_Nodes_background_Network.csv
    #         Final_enriched.csv
# Out:
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-807.csv 0
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-66.csv 1
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-289.csv 2
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-522.csv 3
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-474.csv 4
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-7.csv 5
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-577.csv 6
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-938.csv 7
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-463.csv 8
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-41.csv 9
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-305.csv 10
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-235.csv 11
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-473.csv 12
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-170.csv 13
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-209.csv 14
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-901.csv 15
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-710.csv 16
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-189.csv 17
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-877.csv 18
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-32.csv 19
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-698.csv 20
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-869.csv 21
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-920.csv 22
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-743.csv 23
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-686.csv 24
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-493.csv 25
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-603.csv 26
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-895.csv 27
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-511.csv 28
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-555.csv 29
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-273.csv 30
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-883.csv 31
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-943.csv 32
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-87.csv 33
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-363.csv 34
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-443.csv 35
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-162.csv 36
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-301.csv 37
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-990.csv 38
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-46.csv 39
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-436.csv 40
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-153.csv 41
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-659.csv 42
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-487.csv 43
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-936.csv 44
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-9.csv 45
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-638.csv 46
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-105.csv 47
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-33.csv 48
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-523.csv 49
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-896.csv 50
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-831.csv 51
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-535.csv 52
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-465.csv 53
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-484.csv 54
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-729.csv 55
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-779.csv 56
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-476.csv 57
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-31.csv 58
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-644.csv 59
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-855.csv 60
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-387.csv 61
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-947.csv 62
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-217.csv 63
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-707.csv 64
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-814.csv 65
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-508.csv 66
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-393.csv 67
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-72.csv 68
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-652.csv 69
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-328.csv 70
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-844.csv 71
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-632.csv 72
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-439.csv 73
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-433.csv 74
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-928.csv 75
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-285.csv 76
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-332.csv 77
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-408.csv 78
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-454.csv 79
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-325.csv 80
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-324.csv 81
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-83.csv 82
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-583.csv 83
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-925.csv 84
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-829.csv 85
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-955.csv 86
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-458.csv 87
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-352.csv 88
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-357.csv 89
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-207.csv 90
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-663.csv 91
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-249.csv 92
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-61.csv 93
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-284.csv 94
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-728.csv 95
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-43.csv 96
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-606.csv 97
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-122.csv 98
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-872.csv 99
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-15.csv 100
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-104.csv 101
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-566.csv 102
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-579.csv 103
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-455.csv 104
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-145.csv 105
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-608.csv 106
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-349.csv 107
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-69.csv 108
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-765.csv 109
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-114.csv 110
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-825.csv 111
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-451.csv 112
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-317.csv 113
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-359.csv 114
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-460.csv 115
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-719.csv 116
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-854.csv 117
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-183.csv 118
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-441.csv 119
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-74.csv 120
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-502.csv 121
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-378.csv 122
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-280.csv 123
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-888.csv 124
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-437.csv 125
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-545.csv 126
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-383.csv 127
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-166.csv 128
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-406.csv 129
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-271.csv 130
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-274.csv 131
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-738.csv 132
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-880.csv 133
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-91.csv 134
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-635.csv 135
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-666.csv 136
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-374.csv 137
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-885.csv 138
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-866.csv 139
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-633.csv 140
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-607.csv 141
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-851.csv 142
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-449.csv 143
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-248.csv 144
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-407.csv 145
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-681.csv 146
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-870.csv 147
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-215.csv 148
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-47.csv 149
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-761.csv 150
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-119.csv 151
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-241.csv 152
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-853.csv 153
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-975.csv 154
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-261.csv 155
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-890.csv 156
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-138.csv 157
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-94.csv 158
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-348.csv 159
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-470.csv 160
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-868.csv 161
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-981.csv 162
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-291.csv 163
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-919.csv 164
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-346.csv 165
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-875.csv 166
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-959.csv 167
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-806.csv 168
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-627.csv 169
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-498.csv 170
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-445.csv 171
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-175.csv 172
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-865.csv 173
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-396.csv 174
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-220.csv 175
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-519.csv 176
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-107.csv 177
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-592.csv 178
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-982.csv 179
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-335.csv 180
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-601.csv 181
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-848.csv 182
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-694.csv 183
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-727.csv 184
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-852.csv 185
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-942.csv 186
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-796.csv 187
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-219.csv 188
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-725.csv 189
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-778.csv 190
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-582.csv 191
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-178.csv 192
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-39.csv 193
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-255.csv 194
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-379.csv 195
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-835.csv 196
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-262.csv 197
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-556.csv 198
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-206.csv 199
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-587.csv 200
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-775.csv 201
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-25.csv 202
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-702.csv 203
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-887.csv 204
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-612.csv 205
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-932.csv 206
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-754.csv 207
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-501.csv 208
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-636.csv 209
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-313.csv 210
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-385.csv 211
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-471.csv 212
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-293.csv 213
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-832.csv 214
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-816.csv 215
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-10.csv 216
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-434.csv 217
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-224.csv 218
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-48.csv 219
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-92.csv 220
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-239.csv 221
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-185.csv 222
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-208.csv 223
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-21.csv 224
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-826.csv 225
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-794.csv 226
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-889.csv 227
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-923.csv 228
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-783.csv 229
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-204.csv 230
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-574.csv 231
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-746.csv 232
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-85.csv 233
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-747.csv 234
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-444.csv 235
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-752.csv 236
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-957.csv 237
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-152.csv 238
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-934.csv 239
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-771.csv 240
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-616.csv 241
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-962.csv 242
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-759.csv 243
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-602.csv 244
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-971.csv 245
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-198.csv 246
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-230.csv 247
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-226.csv 248
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-695.csv 249
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-914.csv 250
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-850.csv 251
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-963.csv 252
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-720.csv 253
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-964.csv 254
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-71.csv 255
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-23.csv 256
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-745.csv 257
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-60.csv 258
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-978.csv 259
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-554.csv 260
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-464.csv 261
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-699.csv 262
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-295.csv 263
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-516.csv 264
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-676.csv 265
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-375.csv 266
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-905.csv 267
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-142.csv 268
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-599.csv 269
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-867.csv 270
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-580.csv 271
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-88.csv 272
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-893.csv 273
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-57.csv 274
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-811.csv 275
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-491.csv 276
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-420.csv 277
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-140.csv 278
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-63.csv 279
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-199.csv 280
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-758.csv 281
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-862.csv 282
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-782.csv 283
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-299.csv 284
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-469.csv 285
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-334.csv 286
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-245.csv 287
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-642.csv 288
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-790.csv 289
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-605.csv 290
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-998.csv 291
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-882.csv 292
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-993.csv 293
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-899.csv 294
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-841.csv 295
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-791.csv 296
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-777.csv 297
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-813.csv 298
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-559.csv 299
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-704.csv 300
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-781.csv 301
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-258.csv 302
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-429.csv 303
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-550.csv 304
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-110.csv 305
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-509.csv 306
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-70.csv 307
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-250.csv 308
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-724.csv 309
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-639.csv 310
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-165.csv 311
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-570.csv 312
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-4.csv 313
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-737.csv 314
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-622.csv 315
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-958.csv 316
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-277.csv 317
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-911.csv 318
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-472.csv 319
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-623.csv 320
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-136.csv 321
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-858.csv 322
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-34.csv 323
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-203.csv 324
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-252.csv 325
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-569.csv 326
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-984.csv 327
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-244.csv 328
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-282.csv 329
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-309.csv 330
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-751.csv 331
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-680.csv 332
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-933.csv 333
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-711.csv 334
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-169.csv 335
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-546.csv 336
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-543.csv 337
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-902.csv 338
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-706.csv 339
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-409.csv 340
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-520.csv 341
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-99.csv 342
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-817.csv 343
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-631.csv 344
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-977.csv 345
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-717.csv 346
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-78.csv 347
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-760.csv 348
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-450.csv 349
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-552.csv 350
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-967.csv 351
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-812.csv 352
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-267.csv 353
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-298.csv 354
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-792.csv 355
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-242.csv 356
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-499.csv 357
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-892.csv 358
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-221.csv 359
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-768.csv 360
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-769.csv 361
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-671.csv 362
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-949.csv 363
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-789.csv 364
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-960.csv 365
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-438.csv 366
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-186.csv 367
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-951.csv 368
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-62.csv 369
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-643.csv 370
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-976.csv 371
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-176.csv 372
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-810.csv 373
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-38.csv 374
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-537.csv 375
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-588.csv 376
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-916.csv 377
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-677.csv 378
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-411.csv 379
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-115.csv 380
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-655.csv 381
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-319.csv 382
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-67.csv 383
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-589.csv 384
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-548.csv 385
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-137.csv 386
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-80.csv 387
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-108.csv 388
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-419.csv 389
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-624.csv 390
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-111.csv 391
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-619.csv 392
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-392.csv 393
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-232.csv 394
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-581.csv 395
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-985.csv 396
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-536.csv 397
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-192.csv 398
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-921.csv 399
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-1.csv 400
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-662.csv 401
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-558.csv 402
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-822.csv 403
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-370.csv 404
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-553.csv 405
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-290.csv 406
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-873.csv 407
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-931.csv 408
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-833.csv 409
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-247.csv 410
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-860.csv 411
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-442.csv 412
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-753.csv 413
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-263.csv 414
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-19.csv 415
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-368.csv 416
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-147.csv 417
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-210.csv 418
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-529.csv 419
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-98.csv 420
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-65.csv 421
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-780.csv 422
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-837.csv 423
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-478.csv 424
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-721.csv 425
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-27.csv 426
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-510.csv 427
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-389.csv 428
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-237.csv 429
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-690.csv 430
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-163.csv 431
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-35.csv 432
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-918.csv 433
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-948.csv 434
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-417.csv 435
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-381.csv 436
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-799.csv 437
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-922.csv 438
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-847.csv 439
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-44.csv 440
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-834.csv 441
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-281.csv 442
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-736.csv 443
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-194.csv 444
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-617.csv 445
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-544.csv 446
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-604.csv 447
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-956.csv 448
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-793.csv 449
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-997.csv 450
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-489.csv 451
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-1000.csv 452
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-426.csv 453
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-382.csv 454
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-703.csv 455
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-797.csv 456
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-533.csv 457
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-337.csv 458
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-744.csv 459
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-692.csv 460
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-182.csv 461
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-391.csv 462
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-846.csv 463
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-849.csv 464
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-344.csv 465
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-910.csv 466
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-456.csv 467
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-371.csv 468
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-979.csv 469
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-269.csv 470
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-16.csv 471
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-428.csv 472
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-160.csv 473
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-926.csv 474
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-133.csv 475
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-715.csv 476
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-722.csv 477
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-828.csv 478
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-970.csv 479
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-614.csv 480
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-542.csv 481
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-988.csv 482
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-397.csv 483
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-318.csv 484
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-739.csv 485
# ...
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-991.csv 839
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-654.csv 840
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-400.csv 841
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-423.csv 842
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-830.csv 843
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-398.csv 844
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-935.csv 845
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-58.csv 846
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-503.csv 847
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-734.csv 848
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-840.csv 849
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-946.csv 850
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-735.csv 851
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-341.csv 852
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-320.csv 853
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-225.csv 854
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-342.csv 855
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-353.csv 856
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-836.csv 857
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-364.csv 858
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-718.csv 859
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-231.csv 860
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-740.csv 861
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-24.csv 862
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-55.csv 863
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-803.csv 864
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-321.csv 865
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-679.csv 866
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-904.csv 867
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-174.csv 868
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-347.csv 869
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-109.csv 870
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-394.csv 871
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-669.csv 872
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-307.csv 873
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-435.csv 874
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-818.csv 875
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-97.csv 876
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-302.csv 877
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-495.csv 878
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-549.csv 879
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-156.csv 880
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-714.csv 881
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-361.csv 882
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-878.csv 883
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-467.csv 884
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-798.csv 885
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-340.csv 886
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-567.csv 887
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-494.csv 888
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-620.csv 889
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-151.csv 890
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-447.csv 891
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-50.csv 892
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-424.csv 893
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-974.csv 894
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-874.csv 895
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-994.csv 896
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-246.csv 897
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-11.csv 898
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-845.csv 899
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-670.csv 900
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-190.csv 901
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-767.csv 902
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-143.csv 903
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-12.csv 904
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-29.csv 905
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-507.csv 906
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-81.csv 907
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-164.csv 908
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-369.csv 909
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-146.csv 910
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-772.csv 911
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-367.csv 912
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-482.csv 913
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-961.csv 914
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-197.csv 915
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-821.csv 916
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-756.csv 917
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-452.csv 918
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-457.csv 919
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-496.csv 920
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-992.csv 921
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-750.csv 922
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-490.csv 923
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-672.csv 924
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-292.csv 925
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-937.csv 926
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-413.csv 927
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-843.csv 928
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-427.csv 929
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-373.csv 930
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-954.csv 931
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-479.csv 932
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-132.csv 933
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-665.csv 934
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-173.csv 935
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-630.csv 936
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-336.csv 937
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-213.csv 938
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-651.csv 939
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-372.csv 940
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-741.csv 941
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-154.csv 942
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-857.csv 943
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-82.csv 944
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-786.csv 945
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-664.csv 946
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-701.csv 947
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-304.csv 948
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-800.csv 949
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-894.csv 950
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-49.csv 951
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-130.csv 952
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-73.csv 953
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-705.csv 954
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-764.csv 955
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-275.csv 956
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-842.csv 957
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-972.csv 958
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-924.csv 959
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-762.csv 960
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-264.csv 961
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-521.csv 962
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-37.csv 963
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-404.csv 964
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-157.csv 965
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-950.csv 966
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-205.csv 967
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-766.csv 968
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-684.csv 969
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-191.csv 970
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-410.csv 971
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-973.csv 972
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-539.csv 973
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-763.csv 974
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-861.csv 975
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-784.csv 976
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-515.csv 977
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-827.csv 978
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-118.csv 979
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-640.csv 980
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-563.csv 981
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-700.csv 982
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-688.csv 983
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-134.csv 984
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-530.csv 985
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-338.csv 986
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-564.csv 987
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-431.csv 988
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-674.csv 989
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-996.csv 990
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-184.csv 991
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-578.csv 992
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-356.csv 993
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-528.csv 994
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-422.csv 995
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-40.csv 996
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-399.csv 997
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-168.csv 998
# /home/mplace/projects/forMatt/Phospho_Network/forPaper/randomBgNtwk/rewired-BG-network-135.csv 999
